# %%
from matplotlib import pyplot as plt
from scipy.stats import linregress
import numpy as np
from sklearn import datasets
import pandas as pd

# %%
plays_df = pd.read_csv('../base_datasets/plays.csv')
plays_df.head()
# Out:
#        gameId  playId  ballCarrierId ballCarrierDisplayName  \
# 0  2022100908    3537          48723           Parker Hesse
# 1  2022091103    3126          52457         Chase Claypool
# 2  2022091111    1148          42547          Darren Waller
# 3  2022100212    2007          46461             Mike Boone
# 4  2022091900    1372          47857       Devin Singletary
#
#                                      playDescription  quarter  down  \
# 0  (7:52) (Shotgun) M.Mariota pass short middle t...        4     1
# 1  (7:38) (Shotgun) C.Claypool right end to PIT 3...        4     1
# 2  (8:57) D.Carr pass short middle to D.Waller to...        2     2
# 3  (13:12) M.Boone left tackle to DEN 44 for 7 ya...        3     2
# 4  (8:33) D.Singletary right guard to TEN 32 for ...        2     1
#
#    yardsToGo possessionTeam defensiveTeam  ... preSnapHomeTeamWinProbability  \
# 0         10            ATL            TB  ...                      0.976785
# ...

# %%
plays_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12486 entries, 0 to 12485
# Data columns (total 35 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   gameId                            12486 non-null  int64
#  1   playId                            12486 non-null  int64
#  2   ballCarrierId                     12486 non-null  int64
#  3   ballCarrierDisplayName            12486 non-null  object
#  4   playDescription                   12486 non-null  object
#  5   quarter                           12486 non-null  int64
#  6   down                              12486 non-null  int64
#  7   yardsToGo                         12486 non-null  int64
#  8   possessionTeam                    12486 non-null  object
#  9   defensiveTeam                     12486 non-null  object
#  10  yardlineSide                      12319 non-null  object
# ...

# %%
cle_plays_df = plays_df.loc[(plays_df['possessionTeam'] == 'CLE') | (plays_df['defensiveTeam'] == 'CLE')]
cle_plays_df.head()
# Out:
#         gameId  playId  ballCarrierId ballCarrierDisplayName  \
# 23  2022101601     528          46104             Nick Chubb
# 68  2022102300    2314          44841            David Njoku
# 73  2022092200    4028          46104             Nick Chubb
# 77  2022092200    3484          46104             Nick Chubb
# 87  2022091801     428          43380        Jacoby Brissett
#
#                                       playDescription  quarter  down  \
# 23  (7:27) (Shotgun) N.Chubb left tackle to CLV 33...        1     1
# 68  (4:47) (Shotgun) J.Brissett pass short middle ...        3     3
# 73  (1:46) M.Dunn reported in as eligible.  N.Chub...        4     1
# 77  (7:12) N.Chubb right tackle to PIT 47 for 3 ya...        4     1
# 87  (7:39) M.Dunn reported in as eligible.  J.Bris...        1     2
#
#     yardsToGo possessionTeam defensiveTeam  ... preSnapHomeTeamWinProbability  \
# 23         10            CLE            NE  ...                      0.539761
# ...

# %%
cle_plays_df.reset_index(drop=True, inplace=True)
cle_plays_df.head()
# Out:
#        gameId  playId  ballCarrierId ballCarrierDisplayName  \
# 0  2022101601     528          46104             Nick Chubb
# 1  2022102300    2314          44841            David Njoku
# 2  2022092200    4028          46104             Nick Chubb
# 3  2022092200    3484          46104             Nick Chubb
# 4  2022091801     428          43380        Jacoby Brissett
#
#                                      playDescription  quarter  down  \
# 0  (7:27) (Shotgun) N.Chubb left tackle to CLV 33...        1     1
# 1  (4:47) (Shotgun) J.Brissett pass short middle ...        3     3
# 2  (1:46) M.Dunn reported in as eligible.  N.Chub...        4     1
# 3  (7:12) N.Chubb right tackle to PIT 47 for 3 ya...        4     1
# 4  (7:39) M.Dunn reported in as eligible.  J.Bris...        1     2
#
#    yardsToGo possessionTeam defensiveTeam  ... preSnapHomeTeamWinProbability  \
# 0         10            CLE            NE  ...                      0.539761
# ...

# %%
cle_nick_chubb_plays_df=cle_plays_df.loc[cle_plays_df['ballCarrierDisplayName']=='Nick Chubb']
cle_nick_chubb_plays_df.reset_index()
# Out:
#      index      gameId  playId  ballCarrierId ballCarrierDisplayName  \
# 0        0  2022101601     528          46104             Nick Chubb
# 1        2  2022092200    4028          46104             Nick Chubb
# 2        3  2022092200    3484          46104             Nick Chubb
# 3        7  2022101601    1359          46104             Nick Chubb
# 4       10  2022101601    2272          46104             Nick Chubb
# ..     ...         ...     ...            ...                    ...
# 153    744  2022091101    3221          46104             Nick Chubb
# 154    747  2022103100    3132          46104             Nick Chubb
# 155    750  2022103100    1353          46104             Nick Chubb
# 156    755  2022091801    1589          46104             Nick Chubb
# 157    758  2022103100    3406          46104             Nick Chubb
#
#                                        playDescription  quarter  down  \
# ...

# %%
cle_amari_cooper_plays_df=cle_plays_df.loc[cle_plays_df['ballCarrierDisplayName']=='Amari Cooper']
cle_amari_cooper_plays_df.reset_index()
# Out:
#     index      gameId  playId  ballCarrierId ballCarrierDisplayName  \
# 0      43  2022100902     470          42347           Amari Cooper
# 1      61  2022092200    2761          42347           Amari Cooper
# 2      81  2022091801    1072          42347           Amari Cooper
# 3      90  2022092200    2560          42347           Amari Cooper
# 4      94  2022103100    1171          42347           Amari Cooper
# 5     102  2022103100    2536          42347           Amari Cooper
# 6     139  2022091801    2593          42347           Amari Cooper
# 7     141  2022092200     666          42347           Amari Cooper
# 8     191  2022101601    1790          42347           Amari Cooper
# 9     211  2022103100    3087          42347           Amari Cooper
# 10    217  2022091801    1048          42347           Amari Cooper
# 11    236  2022091801    1154          42347           Amari Cooper
# 12    240  2022091101    4150          42347           Amari Cooper
# ...
