# %%
from matplotlib import pyplot as plt
from scipy.stats import linregress
import numpy as np
from sklearn import datasets
import pandas as pd

# %%
week_1_df = pd.read_csv('../resources/tracking_week_1.csv')
week_1_df.head()
# Out:
#        gameId  playId    nflId     displayName  frameId  \
# 0  2022090800      56  35472.0  Rodger Saffold        1
# 1  2022090800      56  35472.0  Rodger Saffold        2
# 2  2022090800      56  35472.0  Rodger Saffold        3
# 3  2022090800      56  35472.0  Rodger Saffold        4
# 4  2022090800      56  35472.0  Rodger Saffold        5
#
#                          time  jerseyNumber club playDirection      x      y  \
# 0  2022-09-08 20:24:05.200000          76.0  BUF          left  88.37  27.27
# 1  2022-09-08 20:24:05.299999          76.0  BUF          left  88.47  27.13
# 2  2022-09-08 20:24:05.400000          76.0  BUF          left  88.56  27.01
# 3  2022-09-08 20:24:05.500000          76.0  BUF          left  88.64  26.90
# 4  2022-09-08 20:24:05.599999          76.0  BUF          left  88.72  26.80
#
#       s     a   dis       o     dir         event
# 0  1.62  1.15  0.16  231.74  147.90           NaN
# 1  1.67  0.61  0.17  230.98  148.53  pass_arrived
# ...

# %%
week_1_df.shape
# Out:
# (1407439, 17)

# %%
#cle_df=plays_df.loc[plays_df['possessionTeam'=='CLE' or 'defensiveTeam'=='CLE']]
cle_week_1_df = week_1_df.loc[(week_1_df['club'] == 'CLE')]
cle_week_1_df.head(40)
# Out:
#             gameId  playId    nflId       displayName  frameId  \
# 172799  2022091101      85  41227.0  Jadeveon Clowney        1
# 172800  2022091101      85  41227.0  Jadeveon Clowney        2
# 172801  2022091101      85  41227.0  Jadeveon Clowney        3
# 172802  2022091101      85  41227.0  Jadeveon Clowney        4
# 172803  2022091101      85  41227.0  Jadeveon Clowney        5
# 172804  2022091101      85  41227.0  Jadeveon Clowney        6
# 172805  2022091101      85  41227.0  Jadeveon Clowney        7
# 172806  2022091101      85  41227.0  Jadeveon Clowney        8
# 172807  2022091101      85  41227.0  Jadeveon Clowney        9
# 172808  2022091101      85  41227.0  Jadeveon Clowney       10
# 172809  2022091101      85  41227.0  Jadeveon Clowney       11
# 172810  2022091101      85  41227.0  Jadeveon Clowney       12
# 172811  2022091101      85  41227.0  Jadeveon Clowney       13
# 172812  2022091101      85  41227.0  Jadeveon Clowney       14
# ...

# %%
cle_plays_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 760 entries, 23 to 12471
# Data columns (total 35 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   gameId                            760 non-null    int64
#  1   playId                            760 non-null    int64
#  2   ballCarrierId                     760 non-null    int64
#  3   ballCarrierDisplayName            760 non-null    object
#  4   playDescription                   760 non-null    object
#  5   quarter                           760 non-null    int64
#  6   down                              760 non-null    int64
#  7   yardsToGo                         760 non-null    int64
#  8   possessionTeam                    760 non-null    object
#  9   defensiveTeam                     760 non-null    object
#  10  yardlineSide                      745 non-null    object
#  11  yardlineNumber                    760 non-null    int64
# ...
