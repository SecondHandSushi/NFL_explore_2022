# %%
from matplotlib import pyplot as plt
from scipy.stats import linregress
import numpy as np
from sklearn import datasets
import pandas as pd

# %%
week_1_df = pd.read_csv('../base_datasets/tracking_week_1.csv')
week_1_df.head()
# Out:
#        gameId  playId    nflId     displayName  frameId  \
# 0  2022090800      56  35472.0  Rodger Saffold        1
# 1  2022090800      56  35472.0  Rodger Saffold        2
# 2  2022090800      56  35472.0  Rodger Saffold        3
# 3  2022090800      56  35472.0  Rodger Saffold        4
# 4  2022090800      56  35472.0  Rodger Saffold        5
#
#                          time  jerseyNumber club playDirection      x      y  \
# 0  2022-09-08 20:24:05.200000          76.0  BUF          left  88.37  27.27
# 1  2022-09-08 20:24:05.299999          76.0  BUF          left  88.47  27.13
# 2  2022-09-08 20:24:05.400000          76.0  BUF          left  88.56  27.01
# 3  2022-09-08 20:24:05.500000          76.0  BUF          left  88.64  26.90
# 4  2022-09-08 20:24:05.599999          76.0  BUF          left  88.72  26.80
#
#       s     a   dis       o     dir         event
# 0  1.62  1.15  0.16  231.74  147.90           NaN
# 1  1.67  0.61  0.17  230.98  148.53  pass_arrived
# ...

# %%
week_1_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1407439 entries, 0 to 1407438
# Data columns (total 17 columns):
#  #   Column         Non-Null Count    Dtype
# ---  ------         --------------    -----
#  0   gameId         1407439 non-null  int64
#  1   playId         1407439 non-null  int64
#  2   nflId          1346246 non-null  float64
#  3   displayName    1407439 non-null  object
#  4   frameId        1407439 non-null  int64
#  5   time           1407439 non-null  object
#  6   jerseyNumber   1346246 non-null  float64
#  7   club           1407439 non-null  object
#  8   playDirection  1407439 non-null  object
#  9   x              1407439 non-null  float64
#  10  y              1407439 non-null  float64
#  11  s              1407439 non-null  float64
#  12  a              1407439 non-null  float64
#  13  dis            1407439 non-null  float64
#  14  o              1346397 non-null  float64
#  15  dir            1346397 non-null  float64
# ...

# %%
week_1_df['jerseyNumber'] = df['jerseyNumber'].astype(int)
# Out:
# (1407439, 17)

# %%
cle_week_1_df = week_1_df.loc[(week_1_df['club'] == 'CLE')]
Nick_chubb_df = cle_week_1_df.loc[cle_week_1_df['displayName'] == 'Nick Chubb']
Nick_chubb_df.tail(60)
#cle_week_1_df.head(40)
# Out:
#             gameId  playId    nflId displayName  frameId  \
# 256211  2022091101    3669  46104.0  Nick Chubb       20
# 256212  2022091101    3669  46104.0  Nick Chubb       21
# 256213  2022091101    3669  46104.0  Nick Chubb       22
# 256214  2022091101    3669  46104.0  Nick Chubb       23
# 256215  2022091101    3669  46104.0  Nick Chubb       24
# 256216  2022091101    3669  46104.0  Nick Chubb       25
# 256217  2022091101    3669  46104.0  Nick Chubb       26
# 256218  2022091101    3669  46104.0  Nick Chubb       27
# 256219  2022091101    3669  46104.0  Nick Chubb       28
# 256220  2022091101    3669  46104.0  Nick Chubb       29
# 256221  2022091101    3669  46104.0  Nick Chubb       30
# 256222  2022091101    3669  46104.0  Nick Chubb       31
# 256223  2022091101    3669  46104.0  Nick Chubb       32
# 256224  2022091101    3669  46104.0  Nick Chubb       33
# 256225  2022091101    3669  46104.0  Nick Chubb       34
# ...

# %%
cle_week_1_3707_df = week_1_df.loc[(week_1_df['playId'] == 3707)]
cle_week_1_3707_df.head(40)
# Out:
#             gameId  playId    nflId   displayName  frameId  \
# 256864  2022091101    3707  41264.0  Joel Bitonio        1
# 256865  2022091101    3707  41264.0  Joel Bitonio        2
# 256866  2022091101    3707  41264.0  Joel Bitonio        3
# 256867  2022091101    3707  41264.0  Joel Bitonio        4
# 256868  2022091101    3707  41264.0  Joel Bitonio        5
# 256869  2022091101    3707  41264.0  Joel Bitonio        6
# 256870  2022091101    3707  41264.0  Joel Bitonio        7
# 256871  2022091101    3707  41264.0  Joel Bitonio        8
# 256872  2022091101    3707  41264.0  Joel Bitonio        9
# 256873  2022091101    3707  41264.0  Joel Bitonio       10
# 256874  2022091101    3707  41264.0  Joel Bitonio       11
# 256875  2022091101    3707  41264.0  Joel Bitonio       12
# 256876  2022091101    3707  41264.0  Joel Bitonio       13
# 256877  2022091101    3707  41264.0  Joel Bitonio       14
# 256878  2022091101    3707  41264.0  Joel Bitonio       15
# ...

# %%
cle_week_1_3707_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 713 entries, 256864 to 257576
# Data columns (total 17 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   gameId         713 non-null    int64
#  1   playId         713 non-null    int64
#  2   nflId          682 non-null    float64
#  3   displayName    713 non-null    object
#  4   frameId        713 non-null    int64
#  5   time           713 non-null    object
#  6   jerseyNumber   682 non-null    float64
#  7   club           713 non-null    object
#  8   playDirection  713 non-null    object
#  9   x              713 non-null    float64
#  10  y              713 non-null    float64
#  11  s              713 non-null    float64
#  12  a              713 non-null    float64
#  13  dis            713 non-null    float64
#  14  o              682 non-null    float64
#  15  dir            682 non-null    float64
#  16  event          92 non-null     object
# ...

# %%
#cle_week_1_3707_df['displayName'].nunique()
unique_values = cle_week_1_3707_df['displayName'].unique()
#unique_values = unique_values.reset_index()
#unique_values.info()
unique_values, counts = np.unique(unique_values , return_counts=True)

# Display unique values and their counts
for value, count in zip(unique_values, counts):
    print(f"Value: {value}, Count: {count}")
# Out:
# Value: Amari Cooper, Count: 1
# Value: Bravvion Roy, Count: 1
# Value: Brian Burns, Count: 1
# Value: Donovan Peoples-Jones, Count: 1
# Value: Donte Jackson, Count: 1
# Value: Ethan Pocic, Count: 1
# Value: Frankie Luvu, Count: 1
# Value: Harrison Bryant, Count: 1
# Value: Jacoby Brissett, Count: 1
# Value: James Hudson, Count: 1
# Value: Jaycee Horn, Count: 1
# Value: Jedrick Wills, Count: 1
# Value: Jeremy Chinn, Count: 1
# Value: Joel Bitonio, Count: 1
# Value: Matt Ioannidis, Count: 1
# Value: Michael Dunn, Count: 1
# Value: Myles Hartsfield, Count: 1
# Value: Nick Chubb, Count: 1
# Value: Shaq Thompson, Count: 1
# Value: Wyatt Teller, Count: 1
# Value: Xavier Woods, Count: 1
# Value: Yetur Gross-Matos, Count: 1
# Value: football, Count: 1

# %%
columns_to_drop = ['gameId', 'club']
cle_week_1_df_copy=cle_week_1_df.copy

# %%
play_85_df=cle_week_1_df.loc[cle_week_1_df['playId'] == 85, ['displayName','time',]]
play_85_df.head()
# Out:
#              displayName                        time
# 172799  Jadeveon Clowney  2022-09-11 13:05:42.500000
# 172800  Jadeveon Clowney  2022-09-11 13:05:42.599999
# 172801  Jadeveon Clowney  2022-09-11 13:05:42.700000
# 172802  Jadeveon Clowney  2022-09-11 13:05:42.799999
# 172803  Jadeveon Clowney  2022-09-11 13:05:42.900000

# %%
play_85_df.nunique()
# Out:
# displayName    11
# time           26
# dtype: int64
